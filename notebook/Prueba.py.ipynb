# %%
def display_foto(image):
    from IPython.display import display
    from IPython.display import Image
    return display(Image(filename='image.png', width=500))

# %%
x=66

# %%
dfdf1['Age'].apply("../data/df_spotify_limpio.csv")
# Out:
# 0       Generation Z
# 1       Generation Z
# 2       Generation Z
# 3       Generation Z
# 4       Generation Z
#             ...
# 1152      Millennial
# 1153    Generation Z
# 1154    Generation Z
# 1155      Millennial
# 1156    Generation Z
# Name: Age, Length: 1143, dtype: object

# %%
df1=sp.abrir_csv("../data/df_spotify_limpio.csv")

# %%
df1.columns
# Out:
# Index(['Song_Name', 'Genre', 'Subgenre', 'Subgenre_2', 'Release_Date',
#        'Song_Decade', 'Streams', 'Week_Of_Highest_Charting',
#        'Month_Highest_Charting', 'Season_Highest_Charting',
#        'Year_Highest_Charting', 'Popularity', 'Danceability', 'Energy',
#        'Loudness', 'Speechiness', 'Acousticness', 'Liveness', 'Tempo',
#        'Duration_(Ms)', 'Valence', 'Chord', 'Artist', 'Artist_Followers',
#        'Gender', 'Artist_Generation', 'Type', 'Country'],
#       dtype='object')

# %%
sp.display_foto("../images/music_icon.png",500)

# %%
import sys
sys.path.append("../")
import src.main as sp

# %%
sys.path.append("../")

# %%
me transformas los siguientes imports en este formato : de import pandas a [Pandas](https://pandas.pydata.org/):

# %%
me transformas los siguientes imports en este formato : de import pandas a [Pandas](https://pandas.pydata.org/):
import pandas
import numpy
import folium
import os 
from dotenv import load_dotenv
Selenium
import re
gender_guesser.detector
import numpy as np
import datetime
import sqlalchemy as alch
import sys
import re
import matplotlib.pyplot as plt
import gender_guesser.detector as gender
import requests
import seaborn as sns
import pycountry
import plotly.express as px
import folium

# %%
import src.main as sp

# %%
def guess_gender(name_list):
    #adivinar el genero segun el nombre
    guess = {"Gender": []}
    d = gender.Detector()
    for name in name_list:
        g=d.get_gender(name)
        guess["Gender"].append(g)
    return guess

# %%
sp.display_columns

# %%
import gender_guesser.detector as gender

# %%
d = gender.Detector()
for name in artist:
        g=d.get_gender(name)

# %%
guess_gender(df_name)

# %%
df_name=["Marie","maria"]

# %%
sp.opciones_webscaping

# %%
sp.plot_scatter(df["Artist_Generation"], df["Song_Decade"], "gen", "song", "gen and song")

# %%
plt.scatter(Generacion["Artist_Generation"], Generacion["Song_Decade"])
plt.xlabel('Artist_Generation')
plt.ylabel('Song_Decade')
plt.title('Artist_Generation & Song_Decade')
plt.show()

# %%
df=sp.abrir_csv("data/df_spotify_limpio_completo.csv")

# %%
df.head()

# %%
sp.display_foto("image.png")
