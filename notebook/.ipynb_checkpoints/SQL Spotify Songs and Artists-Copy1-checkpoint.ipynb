# %%
import sys
sys.path.append("../")
import src.main as sp

# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_csv("data/df_spotify_limpio_completo.csv", index_col = 0 )

# %%
df.head()
# Out:
#                                            Song_Name    Genre  \
# 0                                               UGH!      pop
# 1                                   Bigger Than Life      rap
# 2                                         Time Flies  hip hop
# 3                   HOT WIND BLOWS (feat. Lil Wayne)  hip hop
# 4  Wonderful Christmastime - Edited Version / Rem...     rock
#
#            Subgenre       Subgenre_2 Release_Date Song_Decade    Streams  \
# 0             k-pop  k-pop boy group   2020-02-21       2020s  9,991,177
# 1       melodic rap       philly rap   2020-03-06       2020s  9,974,143
# 2  canadian hip hop     canadian pop   2020-05-01       2020s  9,904,749
# 3           hip hop              rap   2021-06-25       2020s  9,889,197
# 4        album rock         art rock   1980-05-16       1980s  9,882,989
#
#   Week_Of_Highest_Charting Month_Highest_Charting Season_Highest_Charting  \
# 0               2020-02-21               February                  Winter
# ...

# %%
df.duplicated(["Song_Name"]).sum()
# Out:
# 0

# %% [markdown]
# ## Connection with SQL

# %%
import sqlalchemy as alch

# %%
from getpass import getpass

# %%
contraseña =getpass("contraseña")
# Out:
# contraseña········

# %%
db_name = "etl_spotify"
conexion = f"mysql+pymysql://root:{contraseña}@localhost/{db_name}"

# %%
engine = alch.create_engine(conexion)

# %% [markdown]
# ## IDs

# %%
#id_songs
idsongs= range(1, len(df) + 1)
df["Idsongs"]=idsongs

# %%
#id_topsongs -sort them in order according to their stream and give them a rating
df.sort_values(by='Streams', inplace=True)

# %%
idtopsongs= range(1, len(df) + 1)
df["IdTopsong"]=idtopsongs

# %%
#idartist
df_idartist=pd.DataFrame(df["Artist"].unique())

# %%
idartist= range(1, len(df_idartist) + 1)
df_idartist["Idartist"]=idartist

# %%
df_idartist.rename(columns = {0: "Artist"}, inplace = True)

# %%
df=df.merge(df_idartist, on= "Artist", how="left")

# %%
df.head()
# Out:
#                          Song_Name    Genre                   Subgenre  \
# 0                Louder than bombs      pop                      k-pop
# 1  Love You Different (feat. BEAM)      pop               canadian pop
# 2      Repeat After Me (Interlude)      r&b  canadian contemporary r&b
# 3                        I Can See  hip hop                    hip hop
# 4           Mood (feat. iann dior)      rap                   cali rap
#
#         Subgenre_2 Release_Date Song_Decade     Streams  \
# 0  k-pop boy group   2020-02-21       2020s  10,016,907
# 1              pop   2021-03-19       2020s  10,024,729
# 2     canadian pop   2020-03-20       2020s  10,058,303
# 3   pittsburgh rap   2020-01-17       2020s  10,086,930
# 4                -   2021-03-26       2020s  10,222,056
#
#   Week_Of_Highest_Charting Month_Highest_Charting Season_Highest_Charting  \
# 0               2020-02-21               February                  Winter
# ...

# %%
#id songcharacteristics

# %%
df_ch=df.loc[:, "Danceability":"Chord"]

# %%
duplicate_rows = df[df.duplicated()]
duplicate_rows #there is no duplicate so id of the caracteristics will be the same as id songs
# Out:
# Empty DataFrame
# Columns: [Song_Name, Genre, Subgenre, Subgenre_2, Release_Date, Song_Decade, Streams, Week_Of_Highest_Charting, Month_Highest_Charting, Season_Highest_Charting, Year_Highest_Charting, Popularity, Danceability, Energy, Loudness, Speechiness, Acousticness, Liveness, Tempo, Duration_(Ms), Valence, Chord, Artist, Artist_Followers, Gender, Artist_Generation, Type, Country, Event_Name, url, Event_Country, Event_City, Event_Longitude, Event_Latitude]
# Index: []

# %%
df["Idsongschar"]=df["Idsongs"]

# %%
#idevent
df_event=pd.DataFrame(df["Event_Name"].unique())

# %%
df_event.head()
# Out:
#                       0
# 0       BTS 14-17 Party
# 1         Justin Bieber
# 2      The Weeknd Grada
# 3             No events
# 4  Nick Cannon w/ SYMBA

# %%
idevent= range(1, len(df_event) + 1)
df_event["Idevent"]=idevent

# %%
df_event.rename(columns = {0: "Event_Name"}, inplace = True)

# %%
df=df.merge(df_event, on= "Event_Name", how="left")

# %%
#idgenre

# %%
df_genre=pd.DataFrame(df["Genre"].unique())

# %%
idgenre= range(1, len(df_genre) + 1)
df_genre["Idgenre"]=idgenre

# %%
df_genre.rename(columns = {0: "Genre"}, inplace = True)

# %%
df=df.merge(df_genre, on= "Genre", how="left")

# %%
#idsubgenre

# %%
def id_sql(Id_column, Id):
    df_id=pd.DataFrame(Id_column.unique())
    id = range(1, len(df_id) + 1)
    df_id[f"Id{Id}"]= id
    df_id.rename(columns = {0: Id}, inplace = True)
    
    return df_id

# %%
df_subgenre=id_sql(df["Subgenre"], "Subgenre")

# %%
df=df.merge(df_subgenre, on= "Subgenre", how="left")

# %%
df["IdGenre_Subgenre"]=df["Idgenre"]+df["IdSubgenre"]

# %%
#idlocation
df_loc=df.groupby(by=['Event_Country', 'Event_City']).size().reset_index()

# %%
df_loc.drop(0, axis=1, inplace=True)

# %%
id = range(1, len(df_loc) + 1)
df_loc["Idloc"]= id

# %%
df=df.merge(df_loc, on= "Event_City", how="left")

# %%
#id long lat
df_coor=id_sql(df["Event_Longitude"], "Event_Longitude")

# %%
df=df.merge(df_coor, on= "Event_Longitude", how="left")

# %% [markdown]
# ## Import data to SQL tables

# %%
sp.display_foto("../images/Spotify_SQL_Diagram.png", 500)

# %% [markdown]
# Event_Location

# %%
for index, row in df.iterrows():
    search_id = engine.execute(f"""select idEventLocation from event_location WHERE idEventLocation = "{row['Idloc']}";""")
    
    if len(list(search_id)) > 0: 
        "sorry,this id already exists"
    else: 
        engine.execute(f"""
            INSERT INTO event_location (idEventLocation, Event_Country, Event_City) VALUES
            ("{row["Idloc"]}","{row['Event_Country']}", "{row['Event_City']}");""")

# %% [markdown]
# Event_Coordenates

# %%
for index, row in df.iterrows():
    search_id = engine.execute(f"""select idEvent_Coordenates from event_coordenates WHERE idEvent_Coordenates = "{row['IdEvent_Longitude']}";""")
    
    if len(list(search_id)) > 0: 
        "sorry,this id already exists"
    else: 
        engine.execute(f"""
            INSERT INTO event_coordenates (idEvent_Coordenates, Event_Latitude, Event_Longitude, event_location_idEventLocation) VALUES
            ("{row["IdEvent_Longitude"]}","{row['Event_Longitude']}", "{row['Event_Latitude']}", "{row['Idloc']}");""")

# %% [markdown]
# Song_Genre

# %%
for index, row in df.iterrows():
    search_id = engine.execute(f"""select idSong_Genre from song_genre WHERE idSong_Genre = "{row['Idgenre']}";""")
    
    if len(list(search_id)) > 0: 
        "sorry,this id already exists"
    else: 
        engine.execute(f"""
            INSERT INTO song_genre (idSong_Genre, Genre) VALUES
            ("{row["Idgenre"]}","{row['Genre']}");""")

# %% [markdown]
# Song_Subgenres

# %%
for index, row in df.iterrows():
    search_id = engine.execute(f"""select idsong_subgenres from song_subgenres WHERE idsong_subgenres = "{row['IdSubgenre']}";""")
    
    if len(list(search_id)) > 0: 
        "sorry,this id already exists"
    else: 
        engine.execute(f"""
            INSERT INTO song_subgenres (idsong_subgenres, Subgenre, Subgenre2, song_genre_idSong_Genre) VALUES
            ("{row["IdSubgenre"]}","{row['Subgenre']}", "{row['Subgenre_2']}", "{row['Idgenre']}");""")

# %% [markdown]
# Artists

# %%
for index, row in df.iterrows():
    search_id = engine.execute(f"""select idArtist from artists WHERE idArtist = '{row["Idartist"]}';""")
    
    if len(list(search_id)) > 0: 
        "sorry,this id already exists"
    else: 
        engine.execute(f"""
            INSERT INTO artists (idArtist, Artist_Name, Artist_Followers, Gender, Artist_Generation, Artist_Type, Artist_Country,  Event_Name) VALUES
            ("{row["Idartist"]}","{row["Artist"]}", "{row["Artist_Followers"]}", "{row["Gender"]}", "{row["Artist_Generation"]}", "{row["Type"]}", "{row["Country"]}", "{row["Event_Name"]}");""")

# %% [markdown]
# Events

# %% [markdown]
# As there are several without events I am going to load them with a df that I am going to create

# %%
df_e = df[["Idevents", "Event_Name", "url", "Idloc", "Idartist"]].drop_duplicates(subset='Event_Name', keep='first')

# %%
df_e=df_e.drop(3)

# %%
df_e=df_e.reset_index(drop=True)

# %%
idevent= range(1, len(df_e) + 1)
df_e["Idevents"]=idevent #rehago el Id_event

# %%
for index, row in df_e.iterrows():
    search_id = engine.execute(f"""select idEvents from events WHERE idEvents = '{row["Idevents"]}';""")
    
    if len(list(search_id)) > 0: 
        "sorry,this id already exists"
    else: 
        try:
            engine.execute(f"""
                INSERT INTO events (idEvents, Event_Name, Url, event_location_idEventLocation, artists_idArtist) VALUES
                ("{row["Idevents"]}","{row["Event_Name"]}", "{row["url"]}", "{row["Idloc"]}", "{row["Idartist"]}");""")
        except:
                print(row["Event_Name"])
# Out:
# Mad Cool 2023 | Entradas Día 6
# Apache 207 | Box seat in the Ticketmaster Suite

# %% [markdown]
# Song_Characteristics

# %%
for index, row in df.iterrows():
    search_id = engine.execute(f"""select idSong_Characteristics from song_characteristics WHERE idSong_Characteristics = "{row['Idsongs']}";""")
    
    if len(list(search_id)) > 0: 
        "sorry,this id already exists"
    else: 
        engine.execute(f"""
            INSERT INTO song_characteristics (idSong_Characteristics, Danceability, Energy, Loudness, Speechiness, Acousticness, Liveness, Tempo, Duration, Valence, Chord) VALUES
            ("{row["Idsongschar"]}","{row['Danceability']}","{row["Energy"]}", "{row['Loudness']}", "{row['Speechiness']}", "{row['Acousticness']}", "{row['Liveness']}", "{row['Tempo']}", "{row['Duration_(Ms)']}", "{row['Valence']}", "{row['Chord']}");""")

# %% [markdown]
# Songs

# %%
df["Song_Name"] = df["Song_Name"].str.replace('"', "")

# %%
for index, row in df.iterrows():
    search_id = engine.execute(f"""select idSongs from songs WHERE idSongs = "{row['Idsongs']}";""")
    
    if len(list(search_id)) > 0: 
        "sorry,this id already exists"
    else: 
        engine.execute(f"""
            INSERT INTO songs (idSongs, Song_Name, Artist, Release_Date, Song_Decade, song_genre_idSong_Genre, artists_idArtist, song_characteristics_idSong_Characteristics, song_subgenres_idsong_subgenres) VALUES
                ("{row["Idsongs"]}","{row['Song_Name']}","{row["Artist"]}", "{row['Release_Date']}", "{row['Song_Decade']}", "{row['Idgenre']}", "{row['Idartist']}", "{row['Idsongschar']}", "{row['IdSubgenre']}");""")

# %% [markdown]
# Song_Popularity

# %%
for index, row in df.iterrows():
    search_id = engine.execute(f"""select idTop_Song from song_popularity WHERE idTop_Song = "{row['IdTopsong']}";""")
    
    if len(list(search_id)) > 0: 
        "sorry,this id already exists"
    else: 
        engine.execute(f"""
            INSERT INTO song_popularity (idTop_Song,  Streams, Top_Chart_Week, Top_Chart_Month, Top_Chart_Season , Top_Chart_Year , Popularity_Rate, songs_idSongs, songs_song_genre_idSong_Genre, songs_artists_idArtist) VALUES
                ("{row["IdTopsong"]}","{row['Streams']}","{row["Week_Of_Highest_Charting"]}", "{row['Month_Highest_Charting']}", "{row['Season_Highest_Charting']}", "{row['Year_Highest_Charting']}", "{row['Popularity']}", "{row['Idsongs']}", "{row['Idgenre']}", "{row['Idartist']}");""")

# %%
df.head()
# Out:
#                          Song_Name    Genre                   Subgenre  \
# 0                Louder than bombs      pop                      k-pop
# 1  Love You Different (feat. BEAM)      pop               canadian pop
# 2      Repeat After Me (Interlude)      r&b  canadian contemporary r&b
# 3                        I Can See  hip hop                    hip hop
# 4           Mood (feat. iann dior)      rap                   cali rap
#
#         Subgenre_2 Release_Date Song_Decade     Streams  \
# 0  k-pop boy group   2020-02-21       2020s  10,016,907
# 1              pop   2021-03-19       2020s  10,024,729
# 2     canadian pop   2020-03-20       2020s  10,058,303
# 3   pittsburgh rap   2020-01-17       2020s  10,086,930
# 4                -   2021-03-26       2020s  10,222,056
#
#   Week_Of_Highest_Charting Month_Highest_Charting Season_Highest_Charting  \
# 0               2020-02-21               February                  Winter
# ...
